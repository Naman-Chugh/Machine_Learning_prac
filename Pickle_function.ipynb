# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv('C:/Users/MSI1/OneDrive/Desktop/Machine Learning/01Linear Regression/Prac.csv')

# %%
df.head()
# Out:
#    Area    Price
# 0  1200  3500000
# 1  1500  4000000
# 2  1800  4500000
# 3  2400  5200000
# 4  3000  6000000

# %%
get_ipython().run_line_magic('matplotlib', 'inline')
plt.xlabel("Area in Sq Ft")
plt.ylabel("Price")
plt.title("Price v/s Area")
plt.ticklabel_format(style='plain')
plt.scatter(df.Area, df.Price, color="green")

# %%
reg = linear_model.LinearRegression()
reg.fit(df[["Area"]], df.Price)
# Out:
# LinearRegression()

# %%
reg.predict([[2250]])
# Out:
# C:\Users\MSI1\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([5007758.62068966])

# %%
get_ipython().run_line_magic('matplotlib', 'inline')
plt.xlabel("Area in Sq Ft")
plt.ylabel("Price")
plt.title("Price v/s Area")
plt.ticklabel_format(style='plain')
plt.scatter(df.Area, df.Price, color="green")
plt.plot(df.Area, reg.predict(df[["Area"]]))
plt.grid()

# %%
import pickle

# %%
#Saving Model
with open('model_pickle','wb') as file:
    pickle.dump(reg,file)

# %%
#Checking Default Directory where model is saved
import os

current_directory = os.getcwd()
print(current_directory)
# Out:
# C:\Users\MSI1

# %%
#loading model
with open('model_pickle','rb') as file:
    mp = pickle.load(file)

# %%
mp.predict([[4000]])
# Out:
# C:\Users\MSI1\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([7391379.31034483])
